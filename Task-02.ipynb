# %%
#Importing all Required Libaries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from warnings import filterwarnings
filterwarnings(action='ignore')

# %%
# Loading the Dataset
df = pd.read_csv('Titanic-Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#display first five rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#displaying last five rows
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# Showing no. of rows and columns of dataset
df.shape
# Out:
# (891, 12)

# %%
# Checking for data types
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#showing inforamation about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#showing statistical summary
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# checking for duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
# checking for null values
nv = df.isna().sum().sort_values(ascending=False)

# %%
nv = nv[nv>0]

# %%
nv
# Out:
# Cabin       687
# Age         177
# Embarked      2
# dtype: int64

# %%
# Cheecking what percentage column contain missing values
df.isnull().sum().sort_values(ascending=False)*100/len(df)
# Out:
# Cabin          77.104377
# Age            19.865320
# Embarked        0.224467
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# dtype: float64

# %%
# Since Cabin Column has more than 75 % null values .So , we will drop this column
df.drop(columns = 'Cabin', axis = 1, inplace = True)
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
# Filling Null Values in Age column with mean values of age column
df['Age'].fillna(df['Age'].mean(),inplace=True)

# filling null values in Embarked Column with mode values of embarked column
df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)

# %%
# checking for null values
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# Finding no. of unique values in each column of dataset
df[['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Embarked']].nunique().sort_values()
# Out:
# Survived         2
# Sex              2
# Pclass           3
# Embarked         3
# SibSp            7
# Parch            7
# Age             89
# Fare           248
# Ticket         681
# PassengerId    891
# Name           891
# dtype: int64

# %%
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
df['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
df.drop(columns=['PassengerId','Name','Ticket'],axis=1,inplace=True)
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
# descriptive statistical analysis of dataset
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Statistical Analysis about categorical columns
df.describe(include='O')
# Out:
#          Sex Embarked
# count    891      891
# unique     2        3
# top     male        S
# freq     577      646

# %%
# Plotting Histplot for Dataset
df.hist(figsize=(10,10),color='blue')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
cat_cols = df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['Sex', 'Embarked'], dtype='object')

# %%
for i in cat_cols:
    print(df[i].value_counts())
    plt.figure(figsize=(5, 5))
    sns.countplot(x=df[i], palette='viridis')
    plt.xlabel(i)
    plt.show()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
d1 = df['Sex'].value_counts()
d1
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# Plotting Percantage Distribution of Sex Column
plt.figure(figsize=(5,5))
plt.pie(d1.values,labels=d1.index,autopct='%.2f%%',colors=['#B041FF','#F98B88'])
plt.title('Percentage Distribution of Sex Column')
plt.legend()
plt.show()

# %%
sns.countplot(x=df['Sex'], hue=df['Survived'], palette='coolwarm') 
plt.title('Distribution of Sex Column Survived Wise')
plt.show()

# %%
d2 = sns.FacetGrid(df, col="Sex",height=5)
d2 = (d2.map(sns.distplot, "Age").add_legend())

# %%
d3 = sns.FacetGrid(df, col="Sex",height=5)
d3 = (d3.map(sns.distplot, "Fare").add_legend())

# %%
plt.hist(df['Age'],color='green',bins=20)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution of Passengers')
plt.show()

# %%
# Age Distribution
sns.histplot(x=df['Age'],kde=True,color='yellow')
plt.title('Age Distribution')
plt.show()

# %%
# Showing Distribution of Age Survived Wise
sns.kdeplot(x=df['Age'],hue=df['Survived'],palette='bwr')
plt.title('Distribution of Age Survived Wise')
plt.show()

# %%
sns.countplot(x=df['Embarked'], hue=df['Sex'], palette='Set2')
plt.title('Distribution of Embarked Sex wise')
plt.show()

# %%
# Showing Distribution of Embarked Survived wise
sns.countplot(x=df['Embarked'],hue=df['Survived'],palette='Set2')
plt.title('Distribution of Embarked Survived wise')
plt.show()

# %%
# Plotting CountPlot for Pclass Column
sns.countplot(x=df['Pclass'],palette='magma')
plt.title('CountPlot for Pclass Column')
plt.show()

# %%
# Showing Distribution of Pclass Sex wise
sns.countplot(x=df['Pclass'],hue=df['Sex'],palette='viridis')
plt.title('Distribution of Pclass Sex wise')
plt.show()

# %%
# Countplot for Parch Column
sns.countplot(x=df['Parch'],palette='magma')
plt.title('Countplot for Parch Column')
plt.show()

# %%
# showing Distribution of Parch Sex wise
sns.countplot(x=df['Parch'],hue=df['Sex'],palette='bwr')
plt.title('Distribution of Parch Sex wise')
plt.show()

# %%
# Showing Distribution of Parch Survived Wise
sns.countplot(x=df['Parch'],hue=df['Survived'],palette='bwr')
plt.title('Distribution of Parch Survived Wise')
plt.show()

# %%
# countplot for SibSp Column
sns.countplot(x=df['SibSp'],palette='viridis')
plt.title('Countplot for SibSp Column')
plt.show()

# %%
# Plotting CountPlot for Survived Column
print(df['Survived'].value_counts())
sns.countplot(x=df['Survived'],palette='magma')
plt.title('CountPlot for Survived Column')
plt.show()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Selecting only numeric columns from the dataset
numeric_columns = df.select_dtypes(include='number')

# Creating a boxplot for numeric columns
sns.boxplot(data=numeric_columns, palette='magma')
plt.title('Boxplot for Numerical Columns')  # Corrected
plt.show()

# %%
# Selecting specific columns
columns = ['Age', 'Fare']

# Calculating quartiles and IQR for each column
for col in columns:
    q1 = np.percentile(df[col], 25)
    q3 = np.percentile(df[col], 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    
    # Filtering outliers for each column
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# Creating a boxplot after removing outliers
sns.boxplot(data=df, palette='magma')
plt.title('Boxplot for dataset after removing outliers')
plt.show()

# %%
# showing Correlation
df.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.268318 -0.067543  0.002503  0.070732  0.247519
# Pclass   -0.268318  1.000000 -0.295718  0.081530  0.072351 -0.594245
# Age      -0.067543 -0.295718  1.000000 -0.294476 -0.139368  0.090532
# SibSp     0.002503  0.081530 -0.294476  1.000000  0.392197  0.376443
# Parch     0.070732  0.072351 -0.139368  0.392197  1.000000  0.320864
# Fare      0.247519 -0.594245  0.090532  0.376443  0.320864  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Showing Correlation Plot
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Plot')  # Corrected
plt.show()

# %%
# Plotting pairplot
sns.pairplot(df,hue='Survived',palette='coolwarm')
plt.show()

# %% [markdown]
# CONCLUSION
# The dataset about Titanic passengers includes lots of details like their names, ages, ticket fares, where they embarked, and more. We've studied this data and found some important things: how many passengers survived, how their ticket class or where they got on the ship affected their chances of surviving, and even how age and gender played a role. We also looked at family relationships and how they impacted survival. This dataset gives us a great way to explore and understand what happened on the Titanic in many different ways.
